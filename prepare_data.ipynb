# %%
# Import packages
import numpy as np
import pandas as pd

# Load data
df = pd.read_parquet('data_exjobb_070425.parquet')
df.head()
# Out:
#   TransactionId  SalePrice        Lat        Lon  BuildingAge  UtilityArea  \
# 0      10006194    3200000  56.742153  16.291778           48          143
# 1      10006232    1700000  57.278909  13.646019           54          120
# 2      10006302    3500000  58.328009  15.103299           47          169
# 3      10006371   11200000  57.739437  14.122176          128          250
# 4      10006399     591000  57.784585  16.146614          112           87
#
#    LotArea  QualityScore  CloseToBeach  EnergyPerformance  ...  \
# 0      480            36             0               60.0  ...
# 1      750            32             0              114.0  ...
# 2      592            30             0                NaN  ...
# 3     3311            30             0               88.0  ...
# 4     3406            28             0              101.0  ...
#
#   MunicipalityMoveInFromCountyFrac  MunicipalityMoveOutToCountyFrac  \
# 0                         0.025551                         0.021314
# 1                         0.010123                         0.013869
# 2                         0.034871                         0.028112
# 3                         0.013410                         0.012764
# 4                         0.006766                         0.006466
#
#    MunicipalityMoveInFrac2yrChangeMean  MunicipalityMoveOutFrac2yrChangeMean  \
# 0                             0.001816                              0.004082
# 1                            -0.007777                              0.006713
# 2                            -0.003267                              0.003278
# 3                            -0.001062                              0.001830
# 4                            -0.001024                             -0.000181
#
#    MunicipalityMoveInFromCountyFrac2yrChangeMean  \
# 0                                       0.000930
# 1                                      -0.001110
# 2                                      -0.000932
# 3                                       0.000457
# 4                                       0.000441
#
#   MunicipalityMoveOutToCountyFrac2yrChangeMean  \
# 0                                     0.003437
# 1                                     0.002518
# 2                                     0.000765
# 3                                     0.000039
# 4                                     0.000045
#
#    MunicipalityPopulationMeanDeviation MedianRentMunicipality  \
# 0                             4.373830                 1155.0
# 1                             1.843030                  999.0
# 2                             1.738860                 1046.0
# 3                             8.857676                 1059.0
# 4                             2.279611                  909.0
#
#    MedianRentMunicipality2yrFracChangeMean  \
# 0                                 0.091030
# 1                                 0.013451
# 2                                 0.075010
# 3                                 0.061507
# 4                                 0.009151
#
#    MedianRentMunicipalityMeanDeviation
# 0                             1.123790
# 1                             0.972005
# 2                             1.017735
# 3                             1.030384
# 4                             0.884437
#
# [5 rows x 174 columns]

# %%
dataframe = df.copy()
Targets = pd.DataFrame(dataframe['LogAdjSalePrice202006'])
# print(dataframe[f'{dataframe.axes[1][0]}'])
to_drop = ['TransactionId', 'BaseAreaName', 'DesoArea', 'geometry', 'DistAnyCity', 'DistAnyWater', 'SalePrice', 'LogAdjSalePrice202006', 'LogSalePrice',
            'AdjSalePrice202006']

dataframe = dataframe.drop(to_drop, axis=1)
dataframe.head()
# Out:
#          Lat        Lon  BuildingAge  UtilityArea  LotArea  QualityScore  \
# 0  56.742153  16.291778           48          143      480            36
# 1  57.278909  13.646019           54          120      750            32
# 2  58.328009  15.103299           47          169      592            30
# 3  57.739437  14.122176          128          250     3311            30
# 4  57.784585  16.146614          112           87     3406            28
#
#    CloseToBeach  EnergyPerformance EnergyClass  HasWater  ...  \
# 0             0               60.0           D         1  ...
# 1             0              114.0           D         1  ...
# 2             0                NaN        None         1  ...
# 3             0               88.0           C         1  ...
# 4             0              101.0           F         1  ...
#
#    MunicipalityMoveInFromCountyFrac  MunicipalityMoveOutToCountyFrac  \
# 0                          0.025551                         0.021314
# 1                          0.010123                         0.013869
# 2                          0.034871                         0.028112
# 3                          0.013410                         0.012764
# 4                          0.006766                         0.006466
#
#    MunicipalityMoveInFrac2yrChangeMean  MunicipalityMoveOutFrac2yrChangeMean  \
# 0                             0.001816                              0.004082
# 1                            -0.007777                              0.006713
# 2                            -0.003267                              0.003278
# 3                            -0.001062                              0.001830
# 4                            -0.001024                             -0.000181
#
#   MunicipalityMoveInFromCountyFrac2yrChangeMean  \
# 0                                      0.000930
# 1                                     -0.001110
# 2                                     -0.000932
# 3                                      0.000457
# 4                                      0.000441
#
#    MunicipalityMoveOutToCountyFrac2yrChangeMean  \
# 0                                      0.003437
# 1                                      0.002518
# 2                                      0.000765
# 3                                      0.000039
# 4                                      0.000045
#
#    MunicipalityPopulationMeanDeviation  MedianRentMunicipality  \
# 0                             4.373830                  1155.0
# 1                             1.843030                   999.0
# 2                             1.738860                  1046.0
# 3                             8.857676                  1059.0
# 4                             2.279611                   909.0
#
#    MedianRentMunicipality2yrFracChangeMean  \
# 0                                 0.091030
# 1                                 0.013451
# 2                                 0.075010
# 3                                 0.061507
# 4                                 0.009151
#
#    MedianRentMunicipalityMeanDeviation
# 0                             1.123790
# 1                             0.972005
# 2                             1.017735
# 3                             1.030384
# 4                             0.884437
#
# [5 rows x 164 columns]

# %%
Targets.head()
Targets.to_parquet('ready_targets.parquet')

# %%
def change_data(dataframe_original):
    """Takes a dataframe and finds the columns with values that are non-numerical and assigns each unique non-numerical value a numerical value."""
    dataframe = dataframe_original.copy()
    # rows = np.shape(dataframe)[0]
    cols = np.shape(dataframe)[1]
    print(type(dataframe))
    # print(cols, rows)

    for col in range(cols):
        c = type(dataframe.iloc[0, col]) # Value of the first element in column i row 1
        # print(c)
        if c != np.float64 and c != np.int64:
            a = dataframe.iloc[:, col].unique()   # Gives the unique values of a given column
            number_of_unique_values = np.shape(a)[0]
            b = np.linspace(1, number_of_unique_values, number_of_unique_values) / number_of_unique_values
            # a.reshape(len(a),1)
            # print(np.shape(a), a, "a[0]", a[0], type(a[0]))
            """
            b = np.zeros(number_of_unique_values)
            for j in range(number_of_unique_values):
                b[j] = j / number_of_unique_values
            """
            changed_data = pd.DataFrame(dataframe[f'{dataframe.axes[1][col]}'].copy())
            # print("changed_data", changed_data, " dataframe", dataframe[f'{dataframe.axes[1][col]}'])
            # print("changed data", type(changed_data))
            for j in range(number_of_unique_values):
                # print("col",col)
                # print(dataframe[f'{dataframe.axes[1][col]}'])
                # changed_data = dataframe[f'{dataframe.axes[1][col]}'].copy()
                
                # print(j, "type", type(a[j]), type(b[j]))
                # print("value", a[j], b[j])
                if a[j] == None:
                    changed_data = changed_data.replace('None', b[j])
                else:
                    changed_data = changed_data.replace(a[j], b[j], regex=False)
                    
                    
            print("changed data", changed_data)
            dataframe[f'{dataframe.axes[1][col]}'] = changed_data
            print("dataframe", dataframe[f'{dataframe.axes[1][col]}'])
            """
            for row in range(rows):
                for j in range(number_of_unique_values):
                    if dataframe.iloc[row, col] == a[j]:
                        dataframe.iloc[row, col] = b[j]"""
            

    return dataframe.fillna(0) # Returns the changed data with NaN values changed to zero.

# %%
dataframe = df.iloc[:, 1:15].copy()
# print(dataframe.iloc[1, 10])
# print(dataframe[5, f'{dataframe.axes[1][15]}'])
changed_data = change_data(dataframe)
print(changed_data, np.shape(changed_data))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# changed data        EnergyClass
# 0            0.125
# 1            0.125
# 2              NaN
# 3            0.375
# 4            0.500
# ...            ...
# 91675        0.750
# 91676        0.875
# 91677        0.750
# 91678          NaN
# 91679        0.125
#
# [91630 rows x 1 columns]
# dataframe 0        0.125
# 1        0.125
# 2          NaN
# 3        0.375
# 4        0.500
#          ...
# 91675    0.750
# 91676    0.875
# 91677    0.750
# 91678      NaN
# 91679    0.125
# Name: EnergyClass, Length: 91630, dtype: float64
#        SalePrice        Lat        Lon  BuildingAge  UtilityArea  LotArea  \
# 0        3200000  56.742153  16.291778           48          143      480
# 1        1700000  57.278909  13.646019           54          120      750
# 2        3500000  58.328009  15.103299           47          169      592
# 3       11200000  57.739437  14.122176          128          250     3311
# 4         591000  57.784585  16.146614          112           87     3406
# ...          ...        ...        ...          ...          ...      ...
# 91675    4310000  58.659566  16.003465           82          164     1642
# 91676    1550000  57.587832  18.712390           88          108     1770
# 91677    1795000  57.057038  15.046509           33          116     1020
# 91678     920000  57.640386  18.324891           51          169      888
# 91679    2200000  57.810820  14.445280           90          127     1150
#
#        QualityScore  CloseToBeach  EnergyPerformance  EnergyClass  HasWater  \
# 0                36             0               60.0        0.125         1
# 1                32             0              114.0        0.125         1
# 2                30             0                0.0        0.000         1
# 3                30             0               88.0        0.375         1
# 4                28             0              101.0        0.500         1
# ...             ...           ...                ...          ...       ...
# 91675            36             0               98.0        0.750         1
# 91676            30             0              318.0        0.875         0
# 91677            31             0              164.0        0.750         1
# 91678            30             0                0.0        0.000         1
# 91679            31             0              119.0        0.125         1
#
#        HasSewer  TaxRegionIdTp10  BaseAreaId
# 0             1           880008      202321
# 1             1           662006      210047
# 2             1           586013      202312
# 3             0           680305      210044
# 4             1           883900      210046
# ...         ...              ...         ...
# 91675         1           581019      210040
# 91676         0           980044      812318
# 91677         1           780018      210045
# 91678         1           980234      812318
# 91679         1           680233      210044
#
# [91630 rows x 14 columns] (91630, 14)
# /var/folders/s9/fpc42dw53pgc33tc9cwdpsbh0000gp/T/ipykernel_4645/772988301.py:36: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   changed_data = changed_data.replace(a[j], b[j], regex=False)

# %%
def change_data_1(dataframe_original):
    dataframe = dataframe_original.copy()
    changed_data = []
    rows = np.shape(dataframe)[0]
    cols = np.shape(dataframe)[1]

    for i in range(cols):
        c = type(dataframe[f'{dataframe.axes[1][i]}'][1]) # Value of the first element in column i row 1
        if c != float and c != int:
            a = dataframe[f'{dataframe.axes[1][i]}'].unique()   # Gives the unique values of a given column
            number_of_unique_values = np.shape(a)[0]
            b = np.zeros(number_of_unique_values)
            for j in range(number_of_unique_values):
                b[j] = j / number_of_unique_values

            for row in range(rows):
                for j in range(number_of_unique_values):
                    if dataframe[f'{dataframe.axes[1][i]}'][row] == a[j]:
                        dataframe[f'{dataframe.axes[1][i]}'][row] = b[j]


    return changed_data



dataframe = df.iloc[0:100, 0:15].copy()
print(dataframe.iloc[1, 10])
# print(dataframe[5, f'{dataframe.axes[1][15]}'])
changed_data = change_data(df)
print(changed_data, np.shape(changed_data))

# %%
# Export
changed_data = change_data(df)
changed_data.to_parquet('changed_data.parquet')

# %%
df = pd.DataFrame({
    'A': [1, 2, 1],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
})
df.replace({'A': 1, 'B': 5}, 99)

print(df.replace({'A': 1, 'B': 5}, 99))

# %%
df = pd.read_parquet('changed_data.parquet')
df.head()
